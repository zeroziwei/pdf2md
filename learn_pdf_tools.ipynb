# %%
import fitz
doc = fitz.open("./Introduction_to_Linear_Algebra.pdf")
total_pages = doc.page_count
metadata = doc.metadata
is_encrypted = doc.is_encrypted

print(total_pages)
print(metadata)
print(is_encrypted)

toc = doc.get_toc()
print(toc)

page = doc[10]
print(page.get_text())

doc.close()
# Out:
# 584
# {'format': 'PDF 1.6', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'RICOH MP C2003', 'producer': 'RICOH MP C2003', 'creationDate': "D:20180311121446-07'00'", 'modDate': "D:20240405130750+08'00'", 'trapped': '', 'encryption': None}
# False
# ...
